# %% [markdown]
# https://www.acmicpc.net/problem/1463
#
# ![image.png](attachment:image.png)

# %%
x = 10

# %%
d = [0] * (x+1)
for i in range(2, x+1):
    d[i] = d[i-1] + 1
    if i % 2 == 0:
        d[i] = min(d[i], d[i//2]+1)
    if i % 3 == 0:
        d[i] = min(d[i], d[i//3]+1)

# %%
d[x]
# Out:
# 3
